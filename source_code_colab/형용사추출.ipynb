# %%
import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import json
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.tag import pos_tag
import re

n=WordNetLemmatizer()

tx1 = ''
tx2 = ''

#print('***original text***\n')
with open('/content/drive/My Drive/dataset/전처리 전 json/tempe_3000.json', 'rt', encoding='UTF-8') as f:
    for line in f:
        lineobj = json.loads(line)
        tx1 = lineobj['text']       
        tx3 = tx1.lower()
        word_tokens = word_tokenize(tx3)

        result = []
        words = []

        #print(word_tokens)

        #print('\n\n***lemmatize***\n')
        
        tag_l = pos_tag(word_tokens)
        print(tag_l)
        for w in tag_l:
            if w[1][:2] == 'VB':
                words.append(n.lemmatize(w[0], 'v'))
            else:
                words.append(n.lemmatize(w[0]))
                

        
        """
        stop_words = set(stopwords.words('english'))
        stop_words.update(['\'re', '\'d', '\'t', '\'ll', '\'ve', '\'s','\'m', '!', '.', ',', '/', '?', '\"', '@', '%', '&', '*', '=','(',')','{','}', '-', '--', 'u', '...','$', '#', '*', '@', ':', ';', '[',']','~']) 
        stop_words.remove('not')
        
        for w in words:
            if w == 'n\'t':
                w = 'not'
            if w not in stop_words:
                a = re.sub('[^a-zA-Z ]', '', w)
                if a != '':
                    result.append(a) #result에 불용어 제거된 tokens 존재
        """
        #print('\n\n***result***\n', result)
        
        with open('/content/drive/My Drive/temp_상아/token.txt', 'a', encoding='UTF-8') as mf:
            mf.write('[\n')
            mf.write('\n'.join(result))
            mf.write('\n]\n')

post_tag = pos_tag(words)
print('\n-----------------------------------------------------------------------------\n',post_tag)

# %%
import json
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.tag import pos_tag
import re

n=WordNetLemmatizer()

tx1 = ''
tx2 = ''
remove_list = ['NN', 'IN', 'DT', 'MD', 'TO', 'PR', 'CC', 'WD', 'WP']
#print('***original text***\n')
with open('/content/drive/My Drive/dataset/전처리 전 json/tempe_3000.json', 'rt', encoding='UTF-8') as f:
    for line in f:
        lineobj = json.loads(line)
        tx1 = lineobj['text']       
        tx3 = tx1.lower()
        word_tokens = word_tokenize(tx3)

        result = []
        words = []
        nword = []
        #print(word_tokens)

        #print('\n\n***lemmatize***\n')
        
        tag_l = pos_tag(word_tokens)
        
        for w in tag_l:
          if w[1][:2] == 'VB':
            nword.append(w)
            words.append(n.lemmatize(w[0], 'v'))
          elif w[1][:2] in remove_list:
            continue
          else:
            nword.append(w)
            words.append(n.lemmatize(w[0]))
                
        
        stop_words = set(stopwords.words('english'))
        stop_words.update(['\'re', '\'d', '\'t', '\'ll', '\'ve', '\'s','\'m', '!', '.', ',', '/', '?', '\"', '@', '%', '&', '*', '=','(',')','{','}', '-', '--', 'u', '...','$', '#', '*', '@', ':', ';', '[',']','~']) 
        stop_words.remove('not')
        
        for w in words:
          if w == 'n\'t':
            w = 'not'
          if w not in stop_words:
            a = re.sub('[^a-zA-Z ]', '', w)
            if a != '':
              result.append(a) #result에 불용어 제거된 tokens 존재
        
        #print('\n\n***result***\n', result)
        
        tmp=[]
        with open('/content/drive/My Drive/temp_상아/token_lemma2.txt', 'a', encoding='UTF-8') as mf:
            mf.write('[\n')
            post_l = pos_tag(result)
            #print(tag_l)
            #print(nword)
            for i in post_l:
              tmp.append(i[0]+'_'+ i[1])
            print(post_l, '\n')
            mf.write('\n'.join(tmp))
            mf.write('\n]\n')
# Out:
# [('absolutely', 'RB'), ('love', 'VB'), ('many', 'JJ'), ('never', 'RB'), ('fail', 'VBP'), ('impress', 'JJ'), ('unreal', 'JJ'), ('amaze', 'NN'), ('pretty', 'RB'), ('much', 'JJ'), ('best', 'JJS')]
#
# [('love', 'RB'), ('delicious', 'JJ'), ('wish', 'JJ'), ('closer', 'RBR'), ('reasonable', 'JJ'), ('great', 'JJ'), ('not', 'RB'), ('ask', 'VB'), ('else', 'RB')]
#
# ...

# %%
import json
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.tag import pos_tag
import re

n=WordNetLemmatizer()

tx1 = ''
tx2 = ''
remove_list = ['NN', 'IN', 'DT', 'MD', 'TO', 'PR', 'CC', 'WD', 'WP', 'CD']

#print('***original text***\n')
with open('/content/drive/My Drive/dataset/전처리 전 json/tempe_3000.json', 'rt', encoding='UTF-8') as f:
    for line in f:
        lineobj = json.loads(line)
        tx1 = lineobj['text']       
        tx3 = tx1.lower()
        word_token = word_tokenize(tx3)

        result = []
        words = []
        word_tokens=[]
        #print(word_tokens)

        #print('\n\n***lemmatize***\n')
        for w in word_token:
          if 'vegan' in w:
            continue
          elif 'vegetarian' in w:
            continue
          elif 'vegeterian' in w:
            continue
          elif 'chicken' in w:
            continue
          else:
            word_tokens.append(w)
            
        tag_l = pos_tag(word_tokens)
        
        for w in tag_l:
          if w[1][:2] in remove_list:
            continue
          else:
            words.append(w[0])
 
        
        stop_words = set(stopwords.words('english'))
        stop_words.update(['\'re', '\'d', '\'t', '\'ll', '\'ve', '\'s','\'m', '!', '.', ',', '/', '?', '\"', '@', '%', '&', '*', '=','(',')','{','}', '-', '--', 'u', '...','$', '#', '*', '@', ':', ';', '[',']','~']) 
        stop_words.remove('not')
        
        for w in words:
          if w == 'n\'t':
            w = 'not'
          if w not in stop_words:
            a = re.sub('[^a-zA-Z ]', '', w)
            if a != '':
              result.append(a) #result에 불용어 제거된 tokens 존재
        print(result)
        #print('\n\n***result***\n', result)

        with open('/content/drive/My Drive/temp_상아/token_ad.txt', 'a', encoding='UTF-8') as mf:
            mf.write('[\n')
            mf.write('\n'.join(result))
            mf.write('\n]\n')
# Out:
# ['absolutely', 'love', 'many', 'never', 'fails', 'impress', 'unreal', 'amazing', 'pretty', 'much', 'best']
# ['love', 'delicious', 'wish', 'closer', 'reasonable', 'great', 'not', 'ask', 'else']
# ['grew', 'lived', 'love', 'became', 'always', 'craved', 'brought', 'green', 'bic', 'outstanding', 'not', 'believe', 'not', 'perfect', 'right', 'not', 'vegi', 'love', 'cook', 'try', 'shocked', 'opted', 'remove', 'middle', 'double', 'cheese', 'never', 'guessed', 'try', 'crispy', 'fresh', 'also', 'loved', 'much', 'better', 'fav', 'indian', 'not', 'greesy', 'crispy']
# ...

# %%
import json
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer
from nltk.tag import pos_tag
import re

n=WordNetLemmatizer()

tx1 = ''
tx2 = ''
remove_list = ['NN', 'IN', 'DT', 'MD', 'TO', 'PR', 'CC', 'WD', 'WP', 'CD']

#print('***original text***\n')
with open('/content/drive/My Drive/dataset/전처리 전 json/vegas_3000.json', 'rt', encoding='UTF-8') as f:
    for line in f:
        lineobj = json.loads(line)
        tx1 = lineobj['text']       
        tx3 = tx1.lower()
        word_token = word_tokenize(tx3)

        result = []
        words = []
        word_tokens=[]
        #print(word_tokens)

        #print('\n\n***lemmatize***\n')
        for w in word_token:
          if 'vegan' in w:
            continue
          elif 'vegetarian' in w:
            continue
          elif 'vegeterian' in w:
            continue
          elif 'chicken' in w:
            continue
          else:
            word_tokens.append(w)
            
        tag_l = pos_tag(word_tokens)
        
        for w in tag_l:
          if w[1][:2] in remove_list:
            continue
          else:
            words.append(w[0])
 
        
        stop_words = set(stopwords.words('english'))
        stop_words.update(['\'re', '\'d', '\'t', '\'ll', '\'ve', '\'s','\'m', '!', '.', ',', '/', '?', '\"', '@', '%', '&', '*', '=','(',')','{','}', '-', '--', 'u', '...','$', '#', '*', '@', ':', ';', '[',']','~']) 
        stop_words.remove('not')
        
        for w in words:
          if w == 'n\'t':
            w = 'not'
          if w not in stop_words:
            a = re.sub('[^a-zA-Z ]', '', w)
            if a != '':
              result.append(a) #result에 불용어 제거된 tokens 존재
        print(result)
        #print('\n\n***result***\n', result)

        with open('/content/drive/My Drive/temp_상아/vegas_token_ad.txt', 'a', encoding='UTF-8') as mf:
            mf.write('[\n')
            mf.write('\n'.join(result))
            mf.write('\n]\n')
# Out:
# ['bad', 'confuse', 'expected', 'ridiculously', 'top', 'fatladen', 'got', 'high', 'feel', 'come', 'think', 'entertaining', 'wearing', 'pretty', 'funny', 'get', 'keep', 'let', 'spank', 'watching', 'dole', 'pretty', 'hilarious', 'loved', 'medical', 'rendered', 'printed', 'great', 'friendly', 'came', 'relatively', 'quickly', 'started', 'added', 'whipped', 'turns', 'actually', 'thus', 'earning', 'strongest', 'frozen', 'not', 'know', 'really', 'strongest', 'know', 'tastiest', 'frozen', 'childish', 'enough', 'enjoy', 'whipped', 'definitely', 'appreciate', 'delicious', 'fine', 'split', 'single', 'love', 'cook', 'cooked', 'delicious', 'perfectly', 'crisp', 'good', 'well', 'definitely', 'not', 'best', 'vegas', 'great', 'overall', 'please', 'not', 'come', 'not', 'not', 'enjoy', 'high', 'fat', 'much', 'better', 'drunk', 'eating', 'wearing', 'probably', 'done', 'intoxicated']
# ...
